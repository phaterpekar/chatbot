# %%
# !pip install transformers
# !pip install sentence_transformers
# !pip install spacy
# !python -m spacy download en_core_web_lg
# !pip install simpleneighbors
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.18.4)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.6/dist-packages (from transformers) (0.1.91)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.6/dist-packages (from transformers) (0.0.43)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.7)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tokenizers==0.7.0 in /usr/local/lib/python3.6/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (0.15.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.12.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.9)
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.6/dist-packages (0.2.6.1)
# Requirement already satisfied: torch>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from sentence_transformers) (1.5.0+cu101)
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (from sentence_transformers) (3.2.5)
# Requirement already satisfied: transformers>=2.8.0 in /usr/local/lib/python3.6/dist-packages (from sentence_transformers) (2.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sentence_transformers) (0.22.2.post1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from sentence_transformers) (1.18.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from sentence_transformers) (1.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from sentence_transformers) (4.41.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.0.1->sentence_transformers) (0.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk->sentence_transformers) (1.12.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.6/dist-packages (from transformers>=2.8.0->sentence_transformers) (0.1.91)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers>=2.8.0->sentence_transformers) (3.0.12)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.6/dist-packages (from transformers>=2.8.0->sentence_transformers) (0.0.43)
# Requirement already satisfied: tokenizers==0.7.0 in /usr/local/lib/python3.6/dist-packages (from transformers>=2.8.0->sentence_transformers) (0.7.0)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers>=2.8.0->sentence_transformers) (0.7)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers>=2.8.0->sentence_transformers) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers>=2.8.0->sentence_transformers) (2.23.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sentence_transformers) (0.15.1)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers>=2.8.0->sentence_transformers) (7.1.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers>=2.8.0->sentence_transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers>=2.8.0->sentence_transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers>=2.8.0->sentence_transformers) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers>=2.8.0->sentence_transformers) (2020.4.5.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.6/dist-packages (2.2.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (3.0.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (7.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.18.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.6.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (4.41.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy) (46.3.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.9)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (1.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (3.1.0)
# Requirement already satisfied: en_core_web_lg==2.2.5 from https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz#egg=en_core_web_lg==2.2.5 in /usr/local/lib/python3.6/dist-packages (2.2.5)
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.6/dist-packages (from en_core_web_lg==2.2.5) (2.2.4)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.18.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (46.3.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (7.4.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (0.6.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.1.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (4.41.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (2.0.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (3.0.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (2020.4.5.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (2.9)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (1.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')
# Requirement already satisfied: simpleneighbors in /usr/local/lib/python3.6/dist-packages (0.1.0)

# %%
import re
import pandas as pd
import numpy as np
import random
from simpleneighbors import SimpleNeighbors
import spacy, random
from sentence_transformers import SentenceTransformer

# %%
def sentence_mean(nlp, s):
    if s == "":
        s = " "
    doc = nlp(s, disable=['tagger', 'parser'])
    return np.mean(np.array([w.vector for w in doc]), axis=0)

# %%
def processScript(scriptFile) -> pd.DataFrame:
    m_title = scriptFile.name[:4]
    lines = scriptFile.readlines()
    dialogs = [re.sub(r'[\(\[].*?[\)\]]', '', x) for x in lines]
    dialog_df = []

    line_count, scene_count = 1, 1
    poc_lines = {}
    context_list = []
    current_context = []
    for l in dialogs:
        row = l.split(':')

        # if row[0].startswith('SCENE') or row[0].startswith('Scene') or row[0].startswith('END') or row[0].startswith('THE END'):
        if row[0].startswith(('SCENE','Scene','END', 'THE END','Picture')):
            scene_count += 1
            context_list.append(current_context)
            current_context = []
        if len(row) >= 2 and not row[0].startswith('SCENE') and not row[0].startswith('Scene'):
            label = m_title + '_' +'SC' + str(scene_count) + '_' + str(line_count)
            dialog_df.append({'Conv': label,'Character': row[0], 'Dialog': row[1].rstrip()})
            poc_lines[label] = row[1].rstrip()
            current_context.append(label)
            line_count += 1
            # if label == 'POC4_SC2_46':
            #     pass

    dialog_df = pd.DataFrame(dialog_df)
    return dialog_df, poc_lines, context_list

# %%
def sentence_vector_trnf(embedder, s):
    if s == "":
        s = " "
    sentence_embedding = embedder.encode([s])
    return sentence_embedding[0]

# %%
# Process POC scripts
f1 = open("POC1.txt", "r")
f2 = open("POC2.txt", "r")
f3 = open("POC3.txt", "r")

poc1_df, poc1_lines, poc1_context_list = processScript(f1)
poc2_df, poc2_lines, poc2_context_list = processScript(f2)
poc3_df, poc3_lines, poc3_context_list = processScript(f3)
# poc 4 - character convesations are not on a new line. Scene chnge picture ?
# poc 5 - no scene changes

# %%
# Merge Content
all_context_list = poc1_context_list + poc2_context_list + poc3_context_list
all_poc_lines = {**poc1_lines, **poc2_lines, **poc3_lines}

# %%
# Build
responses = {}
for line_ids in all_context_list:
    for first, second in zip(line_ids[:-1], line_ids[1:]):
        responses[first] = second

# Pull Responses from all context
response_sample = random.sample(list(responses.keys()), 2431)

# %%
#  Using GLOVE
nlp = spacy.load('en_core_web_lg')

# %%
nns = SimpleNeighbors(300)
for i, line_id in enumerate(response_sample):
    # show progress
    if i % 10 == 0: print(i, line_id, all_poc_lines[line_id])
    line_text = all_poc_lines[line_id]
    summary_vector = sentence_mean(nlp, line_text)
    if np.any(summary_vector):
        nns.add_one(line_id, summary_vector)
nns.build()
# Out:
# 0 POC3_SC6_109  The Dutchman sails as its captain commands.
# 10 POC1_SC15_419  Stop rubbing it.
# 20 POC3_SC15_842  Your chariot awaits, your highness. The oars are inside.
# 30 POC2_SC11_516  What do you want from me?
# 40 POC2_SC8_347  And if there are Crewmen?
# 50 POC2_SC8_317  No no no no, I heard it was the sea he fell in love with.
# 60 POC2_SC14_646  It’s a mythological creature; I can calls it what I wants!
# 70 POC2_SC3_27   Sorry, mate.  Do you mind if we make a little side trip? I didn’t think so.
# 80 POC3_SC9_297  Blessed sweet westerlies, we’re back!
# 90 POC1_SC22_692   Hold fire.
# 100 POC1_SC13_380  A better one.
# 110 POC2_SC15_663  How did you get here?
# 120 POC1_SC20_636  Cotton ?ere says you missed a bit.
# 130 POC1_SC3_98  Unless, of course, he knew you wouldn?t believe the truth even if he told it to you.
# 140 POC1_SC3_75  Yes, it is, I?ve seen it.
# 150 POC2_SC12_524  Agreed.
# 160 POC1_SC10_322  It'll linger.
# 170 POC2_SC15_680   Lord Beckett desires the contents of that chest. I deliver it
# 180 POC2_SC16_753  We must’ve hit the reef.
# 190 POC2_SC8_289   Mind the boat.
# 200 POC1_SC17_539  Your turn.
# 210 POC2_SC7_249   Have you considered keeping a more watchful eye on her. Maybe just lock her up somewhere?
# 220 POC3_SC14_659  Done.
# 230 POC2_SC13_581   It’s a curious thing, there was a time I would give anything for you to look like that while thinking about me.
# 240 POC1_SC6_204  To blazes with the code.
# 250 POC2_SC13_615  First?
# 260 POC2_SC8_375  Technically, I was only Captain for two years, then I was viciously mutinied upon.
# 270 POC1_SC21_666  Where?s Elizabeth ?
# 280 POC3_SC8_148  Aye aye captain!
# 290 POC3_SC3_60  Ready, aim, fire!
# 300 POC2_SC6_176  These are not going to Jack.
# 310 POC1_SC15_469  Am I not?  Oh.  Palulay?palu-li-la-la-lulu, parlili? parsnip, pasley, par - partner, partner?
# 320 POC2_SC8_329  My eyesight’s as good as ever, just so you know.
# 330 POC1_SC5_159  Excellent work, Mr. Brown . You?ve assisted in the capture of a dangerous fugitive.
# 340 POC3_SC14_722  Man the capstan... keep that powder dry!  Maelstrom!
# 350 POC1_SC17_545   Hey! Hey! Below!
# 360 POC2_SC14_618  I just thought Iâ€™d be married by now. I’m so ready to be married.
# 370 POC3_SC8_136  Help.
# 380 POC1_SC17_556   Why, thank you, Jack .
# 390 POC1_SC15_470  Parley?
# 400 POC1_SC24_752   I can?t breathe.
# 410 POC1_SC24_746   This is wrong.
# 420 POC1_SC15_455  No! She had the medallion. she?s the proper age.
# 430 POC3_SC9_360  You agreed, the Black Pearl was to be mine.
# 440 POC3_SC10_466  Sir?
# 450 POC1_SC18_583  Don?t dare impugn me honor, boy. I agreed she?d go free, but it was you who failed to specify when or where.  Though it does seem a shame to lose something so fine, don?t it lads?
# 460 POC1_SC19_613  I know exactly what you mean, love.
# 470 POC1_SC8_273  What?s your name?
# 480 POC3_SC3_26  Captain Barbossa. Welcome to Singapore.  More steam.
# 490 POC3_SC8_132  Strike your colors, you bloomin’ cockroaches...dead men tell no tales.
# 500 POC1_SC23_737  Huzzah! Huzzah! Huzzah!
# 510 POC3_SC8_138  Ho! Ho!
# 520 POC1_SC7_216   Last time I saw you, you were all alone on a godforsaken island, shrinking into the distance. His fortunes aren?t improved much.
# 530 POC2_SC12_556   It’s not a fate you had to choose for yourself either.
# 540 POC1_SC6_208   Come on!
# 550 POC1_SC11_340  The kid?
# 560 POC3_SC14_695  Is that it?
# 570 POC3_SC13_609  Did I now? I call on Captain Teague, keeper of the code. SeSumbhajee’s assistant
# 580 POC3_SC4_77  Our new friend in Singapore was very specific, nine pieces of eight.
# 590 POC2_SC10_455  The Bo’sun prides himself on cleaving flesh from bone with every swing.
# 600 POC2_SC7_221  Lift it high like a lady’s skirt.
# 610 POC1_SC7_212   My sympathies, friend, you?ve no manner of luck at all.
# 620 POC3_SC9_434  Elizabeth?
# 630 POC1_SC6_165  There you go, Miss.  It was a difficult day for you, I?m sure.
# 640 POC1_SC24_757  And a good man.  If all I have achieved here is that the hangman will earn two pairs of boots instead of one, so be it. At least my conscience will be clear.
# 650 POC2_SC16_776   Haul away!
# 660 POC3_SC13_555  Aye, ya have, but now I need it back.
# 670 POC2_SC13_605  Mother Clarice’s chickens, what happened?
# 680 POC2_SC16_790  We’ll have to try it. We can get away as it takes down the Pearl.
# 690 POC1_SC19_616  Yes, the rum is gone.
# 700 POC3_SC8_187  Why should I sail with any of you? Four of you have tried to kill me in the past, one of you succeeded.
# 710 POC1_SC15_460  It was you who sent Bootstrap to the depths!
# 720 POC1_SC9_293   Rash, Turner, too rash. That is without doubt the worst pirate I have ever seen.
# 730 POC1_SC6_202  I know the code.
# 740 POC1_SC15_441   Sorry, Jack . I?m not going to be your leverage.
# 750 POC3_SC14_840  Aye, Captain Turner.  This ship has a purpose again, and where we are bound, she cannot come. One day ashore, ten years at sea. It’s a steep price for what’s been done.
# 760 POC3_SC14_668  You murdered my father.
# 770 POC2_SC7_209   Stop, stop.  Stop!
# 780 POC3_SC3_17  I trust young Turner to acquire the charts, and you to remember your place in the presence of Capt. Sao Feng.
# 790 POC1_SC9_282  We?re going to steal the ship. That ship?
# 800 POC2_SC8_368  That-a.  You are neither dead nor dying. What is your purpose here?
# 810 POC2_SC12_532  My soul. An eternity of servitude.
# 820 POC2_SC8_333  Is the… jar of dirt going to help?
# 830 POC3_SC11_495  Go. I will follow.
# 840 POC2_SC15_704  Sword!
# 850 POC2_SC8_303   The compass you bartered from me, it cannot lead you to this?
# 860 POC1_SC18_572   No one. He?s no one. A distant cousin of my aunt?s nephew twice removed. Lovely singing voice, though ? eunuch.
# 870 POC3_SC13_615  Hang on a minute.  It shall be the duty of the king to declare war, parlay with said adversaries... fancy that.
# 880 POC1_SC2_44   Ah, Mr. Turner , good to see you again.
# 890 POC1_SC4_116  Father! Commodore, do you really intend to kill my rescuer?
# 900 POC3_SC14_652  Your debt to me is still to be satisfied. One hundred years in service aboard the Dutchman. As a start.
# 910 POC1_SC10_321  Tortuga .  More importantly, it is indeed a sad life that has never breathed deep this sweet, proliferous bouquet that is Tortuga , savvy? What do you think?
# 920 POC3_SC14_649  Will, I’ve been aboard the Dutchman, I understand the burden you bear, but I fear that cause is lost.
# 930 POC3_SC3_31  Because you happen to have a ship a and crew you don’t need?
# 940 POC3_SC3_10  What makes you think she’s alone?
# 950 POC1_SC22_708  Shh!  It?s Elizabeth !
# 960 POC3_SC9_283  The immortal Captain Sparrow.
# 970 POC1_SC21_659   Beg your pardon.
# 980 POC3_SC9_326  It’s our only hope, lad.
# 990 POC2_SC5_110   Jack’s compass? What does Beckett want with that?
# 1000 POC1_SC23_733  He didn?t waste it.
# 1010 POC3_SC9_273  What about port?
# 1020 POC2_SC15_708   Jar of dirt!
# 1030 POC3_SC9_225  Eerie, that’s down right macabre.
# 1040 POC1_SC17_540  We need us a devil?s dowry.
# 1050 POC2_SC5_140  Teen dada, eeseetis.  Eeseetis.
# 1060 POC3_SC14_832  Shiver me timbers! Arrrrrhh!
# 1070 POC2_SC14_629  I love those moments. I like to wave at them as they pass by.
# 1080 POC2_SC17_820  Aye.
# 1090 POC2_SC13_598  Colors?
# 1100 POC1_SC12_357  And the blood to be repaid?
# 1110 POC3_SC13_627  Elizabeth Swann.
# 1120 POC3_SC13_571  Shoot him and cut out his tongue, then shoot his tongue. And trim that scraggly beard.
# 1130 POC2_SC4_65  Somehow I doubt Jack Will consider employment the same as being free.
# 1140 POC2_SC15_678   I can’t let you do that, either. So sorry.
# 1150 POC3_SC6_110  And its captain is to sail it as commanded. I thought you would have learned that when I ordered you to kill your pet. This is no longer your world, Jones. The immaterial has become...immaterial. Admiral.
# 1160 POC3_SC9_243  Come aboard!
# 1170 POC2_SC4_98  Which port?
# 1180 POC3_SC6_104  Does he know?
# 1190 POC2_SC5_126  Can’t say about Jack Sparrow, but this island just south of the straits where I trade spice for… delicious, long pork. Cannot say about Jack. But you’ll find that ship there. A ship with black sails.
# 1200 POC2_SC15_697  Be my guest.
# 1210 POC2_SC12_555  Here.  Take this, too. Now get yourself to land and stay there. It was always in my blood to die at sea.
# 1220 POC1_SC18_591   I?d really rather hoped we were past all this.
# 1230 POC2_SC14_632   No, I have faith in you. You want to know why?
# 1240 POC1_SC21_657  No mistakes this time. He?s only half-Turner. We spill it all!
# 1250 POC3_SC13_556  Sparrow!
# 1260 POC3_SC9_292  He’s rockin’ the ship!
# 1270 POC3_SC7_130  Hold on!
# 1280 POC3_SC14_801  Don’t leave me! I won’t leave you!
# 1290 POC3_SC14_747  It’s too late to alter course now, mateys! Ha ha ha ha!
# 1300 POC2_SC12_530  I challenge Davy Jones.
# 1310 POC3_SC7_125  You’ve doomed us all!
# 1320 POC2_SC7_263  How much do you know about Davy Jones?
# 1330 POC3_SC14_777  You can do nothing without the key!
# 1340 POC3_SC14_795  William! My son!
# 1350 POC2_SC13_562  Yes, they’re signed ‘Lord Cutler Beckett of the East India Trading Company.’
# 1360 POC3_SC14_805  Belay that, or we’ll be a sitting duck.
# 1370 POC2_SC9_416  I know what I want.
# 1380 POC2_SC8_296  Not so well as I’d hoped.  Come.
# 1390 POC1_SC10_315  He was a bloody pirate, a scallywag.
# 1400 POC1_SC22_710  You can?t beat me, Jack .
# 1410 POC3_SC7_128  Malfaiteur en Tombeau, Crocher l’Esplanade, Dans l’Fond d’l’eau!
# 1420 POC3_SC9_257  Rum’s gone too.
# 1430 POC3_SC14_790  Do you?  Heady tonic, holding life and death in the palm of one’s hand.
# 1440 POC2_SC8_389   Uh, Mr. Gibbs?
# 1450 POC2_SC5_114  You would risk your life to save Sparrow’s does not mean that he would do the same for anyone else. Now, where’s that dog with the keys?
# 1460 POC1_SC20_638  Ol? Bootstrap Bill . We knew him. Never sat well with Bootstrap what we did to Jack Sparrow , the mutiny and all. He said it wasn?t right with the Code. That?s why he sent off a piece of the treasure to you as it were. He said we deserved to be cursed? and remain cursed.
# 1470 POC2_SC11_502  To save Will.
# 1480 POC1_SC7_240  And how does a maid come to own a trinket such as that. Family heirloom, perhaps?
# 1490 POC1_SC17_512  You can tell them that after they?ve caught us.
# 1500 POC2_SC8_283  It’s me front I’m worried about.
# 1510 POC2_SC6_175  So I did.  A marriage interrupted.  Or fate intervenes.  You’re making great efforts to ensure Jack Sparrow’s freedom.
# 1520 POC1_SC6_205  She wants to be taken to the Captain. And she?ll go without a fuss. We must honor the Code.
# 1530 POC2_SC8_328   Black spot.
# 1540 POC3_SC14_807  But captain...
# 1550 POC3_SC9_441  Captain? Her!
# 1560 POC1_SC20_648  I don?t care for the situation. Any attempt to storm the caves could turn to an ambush.
# 1570 POC3_SC8_150  This truly is a Godforsaken place.
# 1580 POC1_SC1_3  Mr. Gibbs , that will do!
# 1590 POC2_SC16_724  You aren’t pulling hard enough.
# 1600 POC3_SC8_140  Aye captain.
# 1610 POC1_SC18_587  It goes with your black heart.
# 1620 POC3_SC9_370  There’s no honor in remaining with the losing side. Leaving it for the winning side, that’s just good business.
# 1630 POC2_SC16_780  Hyah! Come on!  Come and get me! I’m over here. Come on!
# 1640 POC2_SC4_83  Ah. So it’s you, then. He shanghaied you into service, eh?
# 1650 POC2_SC9_420  Thanks very much.
# 1660 POC1_SC8_254  No?the pirates who invaded this Fort left Sparrow locked in his cell ergo they are not his allies. Governor, we will establish their most likely course?
# 1670 POC2_SC12_558  They’ll know you helped me.
# 1680 POC2_SC16_788  It’s a lot of open water.
# 1690 POC1_SC17_552  Elizabeth !
# 1700 POC2_SC14_643  Aha.
# 1710 POC3_SC11_488  Come with me.  Quickly!
# 1720 POC3_SC14_737  Think like the whelp... think like the whelp... think like the whelp... half barrel hinges... leverage!  Wish me luck, boys, I’ll need it.
# 1730 POC1_SC6_181  The Black Pearl ? I?ve heard stories. She?s been preying on ships and settlements for near ten years. Never leaves any survivors.
# 1740 POC1_SC13_376  Actually -  borrowed. Borrowed without permission. But with every intention of bringing it back to you.
# 1750 POC3_SC9_279  Ten years years is a long time, mate.
# 1760 POC3_SC9_268  Come again?
# 1770 POC1_SC17_542  She?s not what they?re after.
# 1780 POC3_SC11_496  You’re lying.
# 1790 POC3_SC13_638  It’s not just about living forever, Jackie. The trick is, living with yourself, forever.
# 1800 POC3_SC5_96  Ever gazed upon the green flash, Master Gibbs?
# 1810 POC1_SC6_170  It is a smart match. He?s a fine man; he?s what any woman should dream of marrying.
# 1820 POC3_SC14_740  Nobody move! I dropped me brain.
# 1830 POC3_SC13_606  Aye!
# 1840 POC2_SC16_739   Make fast!
# 1850 POC3_SC9_398  And you can accomplish all this, can you?
# 1860 POC1_SC2_54  About the day we met, do you remember?
# 1870 POC1_SC19_612  Mr. Sparrow ?I?m not entirely sure that I?ve had enough rum to allow that kind of talk.
# 1880 POC3_SC9_235  It’s my father, we’ve made it back. Father here, look here!
# 1890 POC1_SC16_488   What sort of a man trades a man?s life for a ship?
# 1900 POC3_SC9_337  Jack Sparrow, you paid me great insult once.
# 1910 POC1_SC9_296   Search every cabin, every hold, down to the bilges.  Sailors, back to the Interceptor! Now!
# 1920 POC1_SC3_90  What?s your name?
# 1930 POC3_SC13_591  And what fate have you planned for your captors?
# 1940 POC2_SC16_765  Will!
# 1950 POC1_SC13_391  What?s in your head that?s put you in such a fine mood, Captain?
# 1960 POC1_SC18_569  You can?t. I can.
# 1970 POC1_SC20_653  Coward! The commodore ordered ? I have to tell him! The pirates! They?re cursed! They cannot be killed!
# 1980 POC1_SC6_167  Well, I meant you being threatened by that pirate. Sounds terrifying.
# 1990 POC3_SC10_478  Mate, if you choose to lock your heart away, you’ll lose it for certain. If I may lend a machete to your intellectual thicket—avoid the choice altogether. Change the facts. Let someone else dispatch Jones.
# 2000 POC3_SC8_137  Man the yards, you filthy toads!
# 2010 POC2_SC13_584  Oh, don’t be absurd, I trust him, that’s all.
# 2020 POC2_SC11_471  I’m deeply flattered, son, but my first and only love is the sea.
# 2030 POC3_SC14_761  I can set you free, mate.
# 2040 POC2_SC4_68  The Black Pearl?
# 2050 POC2_SC8_279   Her?
# 2060 POC3_SC14_767  I’m a little busy at the moment!
# 2070 POC2_SC11_505  We have our heading.
# 2080 POC2_SC6_189  Come on!  It’s ours for the taking!
# 2090 POC1_SC15_426  Gentlemen, the time has come! Our salvation is nigh! Our torment is near at end.
# 2100 POC1_SC13_384  Aye!
# 2110 POC3_SC13_593  My heart will always belong to you.
# 2120 POC1_SC24_754  Move!
# 2130 POC2_SC8_353   Douse the lamps.
# 2140 POC2_SC6_170  Or else I would not still be here. You sent Will to get you the compass and buy Jack Sparrow, it Will do you no good.
# 2150 POC3_SC13_582  My sweet, you come for me.
# 2160 POC3_SC8_164  There has been a perpetual and virulent lack of discipline aboard my vessel! Why is that, sir?
# 2170 POC3_SC9_319  You stupid fish!
# 2180 POC2_SC13_570  A truly discomforting notion, love.
# 2190 POC3_SC9_410  Excuse me?
# 2200 POC3_SC14_677  Go away!
# 2210 POC2_SC10_466  Where is the chest.
# 2220 POC3_SC14_787  That’s why I brought this!
# 2230 POC2_SC12_529  Aye, anyone.
# 2240 POC1_SC22_694   A moment, please. Elizabeth ? I just want you to know I, uh, I believe you made a very good decision today. Couldn?t be more proud of you.  But, you know, even a good decision if made for the wrong reasons can be a wrong decision.
# 2250 POC3_SC9_245  Someone cast a line!
# 2260 POC2_SC15_719  Here you go.
# 2270 POC3_SC14_828  It’s just good business...
# 2280 POC1_SC9_286   This is either madness or brilliance.
# 2290 POC3_SC14_710  You’re right. Then what shall we die for?  You will listen to me. Listen! The brethren will still be looking here to us, to the Black Pearl to lead, and what will they see? Frightened bilge rats aboard a derelict ship? No! They will see free men, and freedom. And what the enemy will see is the flash of our cannons, they will hear the ring of our swords and they will know what we can do! By the sweat of our brows, and the strength of our backs, and the courage of our hearts... gentlemen, hoist the colors!
# 2300 POC3_SC3_41  More steam!
# 2310 POC1_SC22_716  Any port in the storm.
# 2320 POC1_SC18_559   If any of you as much as thinks the word ?parley,? I?ll have your guts for garters.
# 2330 POC2_SC4_79  I had some help retrieving the Pearl, by the way. Your son.
# 2340 POC2_SC4_100  Jack’s hat! Steer about!
# 2350 POC1_SC15_466  The oars have gone missing. Find them!
# 2360 POC2_SC8_367  I-I-I Will serve.
# 2370 POC1_SC23_731
# 2380 POC1_SC7_220  I didn?t know we was takin? on captives.
# 2390 POC1_SC6_201  Parley. I invoke the right of parley. According to the Code of the brethren, set down by the pirates Morgan and Bartholomew , you have to take me to your Captain.
# 2400 POC1_SC21_668  Shut up! You?re next.
# 2410 POC2_SC10_448  The cat’s out of the bag, Mr. Turner. Your issue Will feel its sting be it at the Bo’sun’s hand or your own.
# 2420 POC2_SC14_644  No no no no no. “Kroken”’s how it’s pronounced in the original Scandinavian, and “Kraken”’s closer to that.
# 2430 POC2_SC4_87  Technically, I –

# %%
# Glove Predictions
sentence = "Good evening, Captain."
picked = nns.nearest(sentence_mean(nlp, sentence), 5)[0]
response_line_id = responses[picked]

print("Your line:\n\t", sentence)
print("Most similar turn:\n\t", all_poc_lines[picked])
print("Response to most similar turn:\n\t", all_poc_lines[response_line_id])
# Out:
# Your line:
# 	 Good evening, Captain.
# Most similar turn:
# 	  Hehehe, welcome to the Crew, lad.
# Response to most similar turn:
# 	  Twelve five’s.  Twelve five’s. Call me a liar, I upped the bid.

# %%
# Using Sentence Embedder
embedder = SentenceTransformer('bert-base-nli-mean-tokens')
# Out:
# 100%|██████████| 405M/405M [00:47<00:00, 8.47MB/s]

# %%
nns_trf = SimpleNeighbors(768)
for i, line_id in enumerate(response_sample):
    # show progress
    if i % 10 == 0: print(i, line_id, all_poc_lines[line_id])
    line_text = all_poc_lines[line_id]
    summary_vector = sentence_vector_trnf(embedder, line_text)
    if np.any(summary_vector):
        nns_trf.add_one(line_id, summary_vector)
nns_trf.build()
# Out:
# 0 POC3_SC6_109  The Dutchman sails as its captain commands.
# 10 POC1_SC15_419  Stop rubbing it.
# 20 POC3_SC15_842  Your chariot awaits, your highness. The oars are inside.
# 30 POC2_SC11_516  What do you want from me?
# 40 POC2_SC8_347  And if there are Crewmen?
# 50 POC2_SC8_317  No no no no, I heard it was the sea he fell in love with.
# 60 POC2_SC14_646  It’s a mythological creature; I can calls it what I wants!
# 70 POC2_SC3_27   Sorry, mate.  Do you mind if we make a little side trip? I didn’t think so.
# 80 POC3_SC9_297  Blessed sweet westerlies, we’re back!
# 90 POC1_SC22_692   Hold fire.
# 100 POC1_SC13_380  A better one.
# 110 POC2_SC15_663  How did you get here?
# 120 POC1_SC20_636  Cotton ?ere says you missed a bit.
# 130 POC1_SC3_98  Unless, of course, he knew you wouldn?t believe the truth even if he told it to you.
# 140 POC1_SC3_75  Yes, it is, I?ve seen it.
# 150 POC2_SC12_524  Agreed.
# 160 POC1_SC10_322  It'll linger.
# 170 POC2_SC15_680   Lord Beckett desires the contents of that chest. I deliver it
# 180 POC2_SC16_753  We must’ve hit the reef.
# 190 POC2_SC8_289   Mind the boat.
# 200 POC1_SC17_539  Your turn.
# 210 POC2_SC7_249   Have you considered keeping a more watchful eye on her. Maybe just lock her up somewhere?
# 220 POC3_SC14_659  Done.
# 230 POC2_SC13_581   It’s a curious thing, there was a time I would give anything for you to look like that while thinking about me.
# 240 POC1_SC6_204  To blazes with the code.
# 250 POC2_SC13_615  First?
# 260 POC2_SC8_375  Technically, I was only Captain for two years, then I was viciously mutinied upon.
# 270 POC1_SC21_666  Where?s Elizabeth ?
# 280 POC3_SC8_148  Aye aye captain!
# 290 POC3_SC3_60  Ready, aim, fire!
# 300 POC2_SC6_176  These are not going to Jack.
# 310 POC1_SC15_469  Am I not?  Oh.  Palulay?palu-li-la-la-lulu, parlili? parsnip, pasley, par - partner, partner?
# 320 POC2_SC8_329  My eyesight’s as good as ever, just so you know.
# 330 POC1_SC5_159  Excellent work, Mr. Brown . You?ve assisted in the capture of a dangerous fugitive.
# 340 POC3_SC14_722  Man the capstan... keep that powder dry!  Maelstrom!
# 350 POC1_SC17_545   Hey! Hey! Below!
# 360 POC2_SC14_618  I just thought Iâ€™d be married by now. I’m so ready to be married.
# 370 POC3_SC8_136  Help.
# 380 POC1_SC17_556   Why, thank you, Jack .
# 390 POC1_SC15_470  Parley?
# 400 POC1_SC24_752   I can?t breathe.
# 410 POC1_SC24_746   This is wrong.
# 420 POC1_SC15_455  No! She had the medallion. she?s the proper age.
# 430 POC3_SC9_360  You agreed, the Black Pearl was to be mine.
# 440 POC3_SC10_466  Sir?
# 450 POC1_SC18_583  Don?t dare impugn me honor, boy. I agreed she?d go free, but it was you who failed to specify when or where.  Though it does seem a shame to lose something so fine, don?t it lads?
# 460 POC1_SC19_613  I know exactly what you mean, love.
# 470 POC1_SC8_273  What?s your name?
# 480 POC3_SC3_26  Captain Barbossa. Welcome to Singapore.  More steam.
# 490 POC3_SC8_132  Strike your colors, you bloomin’ cockroaches...dead men tell no tales.
# 500 POC1_SC23_737  Huzzah! Huzzah! Huzzah!
# 510 POC3_SC8_138  Ho! Ho!
# 520 POC1_SC7_216   Last time I saw you, you were all alone on a godforsaken island, shrinking into the distance. His fortunes aren?t improved much.
# 530 POC2_SC12_556   It’s not a fate you had to choose for yourself either.
# 540 POC1_SC6_208   Come on!
# 550 POC1_SC11_340  The kid?
# 560 POC3_SC14_695  Is that it?
# 570 POC3_SC13_609  Did I now? I call on Captain Teague, keeper of the code. SeSumbhajee’s assistant
# 580 POC3_SC4_77  Our new friend in Singapore was very specific, nine pieces of eight.
# 590 POC2_SC10_455  The Bo’sun prides himself on cleaving flesh from bone with every swing.
# 600 POC2_SC7_221  Lift it high like a lady’s skirt.
# 610 POC1_SC7_212   My sympathies, friend, you?ve no manner of luck at all.
# 620 POC3_SC9_434  Elizabeth?
# 630 POC1_SC6_165  There you go, Miss.  It was a difficult day for you, I?m sure.
# 640 POC1_SC24_757  And a good man.  If all I have achieved here is that the hangman will earn two pairs of boots instead of one, so be it. At least my conscience will be clear.
# 650 POC2_SC16_776   Haul away!
# 660 POC3_SC13_555  Aye, ya have, but now I need it back.
# 670 POC2_SC13_605  Mother Clarice’s chickens, what happened?
# 680 POC2_SC16_790  We’ll have to try it. We can get away as it takes down the Pearl.
# 690 POC1_SC19_616  Yes, the rum is gone.
# 700 POC3_SC8_187  Why should I sail with any of you? Four of you have tried to kill me in the past, one of you succeeded.
# 710 POC1_SC15_460  It was you who sent Bootstrap to the depths!
# 720 POC1_SC9_293   Rash, Turner, too rash. That is without doubt the worst pirate I have ever seen.
# 730 POC1_SC6_202  I know the code.
# 740 POC1_SC15_441   Sorry, Jack . I?m not going to be your leverage.
# 750 POC3_SC14_840  Aye, Captain Turner.  This ship has a purpose again, and where we are bound, she cannot come. One day ashore, ten years at sea. It’s a steep price for what’s been done.
# 760 POC3_SC14_668  You murdered my father.
# 770 POC2_SC7_209   Stop, stop.  Stop!
# 780 POC3_SC3_17  I trust young Turner to acquire the charts, and you to remember your place in the presence of Capt. Sao Feng.
# 790 POC1_SC9_282  We?re going to steal the ship. That ship?
# 800 POC2_SC8_368  That-a.  You are neither dead nor dying. What is your purpose here?
# 810 POC2_SC12_532  My soul. An eternity of servitude.
# 820 POC2_SC8_333  Is the… jar of dirt going to help?
# 830 POC3_SC11_495  Go. I will follow.
# 840 POC2_SC15_704  Sword!
# 850 POC2_SC8_303   The compass you bartered from me, it cannot lead you to this?
# 860 POC1_SC18_572   No one. He?s no one. A distant cousin of my aunt?s nephew twice removed. Lovely singing voice, though ? eunuch.
# 870 POC3_SC13_615  Hang on a minute.  It shall be the duty of the king to declare war, parlay with said adversaries... fancy that.
# 880 POC1_SC2_44   Ah, Mr. Turner , good to see you again.
# 890 POC1_SC4_116  Father! Commodore, do you really intend to kill my rescuer?
# 900 POC3_SC14_652  Your debt to me is still to be satisfied. One hundred years in service aboard the Dutchman. As a start.
# 910 POC1_SC10_321  Tortuga .  More importantly, it is indeed a sad life that has never breathed deep this sweet, proliferous bouquet that is Tortuga , savvy? What do you think?
# 920 POC3_SC14_649  Will, I’ve been aboard the Dutchman, I understand the burden you bear, but I fear that cause is lost.
# 930 POC3_SC3_31  Because you happen to have a ship a and crew you don’t need?
# 940 POC3_SC3_10  What makes you think she’s alone?
# 950 POC1_SC22_708  Shh!  It?s Elizabeth !
# 960 POC3_SC9_283  The immortal Captain Sparrow.
# 970 POC1_SC21_659   Beg your pardon.
# 980 POC3_SC9_326  It’s our only hope, lad.
# 990 POC2_SC5_110   Jack’s compass? What does Beckett want with that?
# 1000 POC1_SC23_733  He didn?t waste it.
# 1010 POC3_SC9_273  What about port?
# 1020 POC2_SC15_708   Jar of dirt!
# 1030 POC3_SC9_225  Eerie, that’s down right macabre.
# 1040 POC1_SC17_540  We need us a devil?s dowry.
# 1050 POC2_SC5_140  Teen dada, eeseetis.  Eeseetis.
# 1060 POC3_SC14_832  Shiver me timbers! Arrrrrhh!
# 1070 POC2_SC14_629  I love those moments. I like to wave at them as they pass by.
# 1080 POC2_SC17_820  Aye.
# 1090 POC2_SC13_598  Colors?
# 1100 POC1_SC12_357  And the blood to be repaid?
# 1110 POC3_SC13_627  Elizabeth Swann.
# 1120 POC3_SC13_571  Shoot him and cut out his tongue, then shoot his tongue. And trim that scraggly beard.
# 1130 POC2_SC4_65  Somehow I doubt Jack Will consider employment the same as being free.
# 1140 POC2_SC15_678   I can’t let you do that, either. So sorry.
# 1150 POC3_SC6_110  And its captain is to sail it as commanded. I thought you would have learned that when I ordered you to kill your pet. This is no longer your world, Jones. The immaterial has become...immaterial. Admiral.
# 1160 POC3_SC9_243  Come aboard!
# 1170 POC2_SC4_98  Which port?
# 1180 POC3_SC6_104  Does he know?
# 1190 POC2_SC5_126  Can’t say about Jack Sparrow, but this island just south of the straits where I trade spice for… delicious, long pork. Cannot say about Jack. But you’ll find that ship there. A ship with black sails.
# 1200 POC2_SC15_697  Be my guest.
# 1210 POC2_SC12_555  Here.  Take this, too. Now get yourself to land and stay there. It was always in my blood to die at sea.
# 1220 POC1_SC18_591   I?d really rather hoped we were past all this.
# 1230 POC2_SC14_632   No, I have faith in you. You want to know why?
# 1240 POC1_SC21_657  No mistakes this time. He?s only half-Turner. We spill it all!
# 1250 POC3_SC13_556  Sparrow!
# 1260 POC3_SC9_292  He’s rockin’ the ship!
# 1270 POC3_SC7_130  Hold on!
# 1280 POC3_SC14_801  Don’t leave me! I won’t leave you!
# 1290 POC3_SC14_747  It’s too late to alter course now, mateys! Ha ha ha ha!
# 1300 POC2_SC12_530  I challenge Davy Jones.
# 1310 POC3_SC7_125  You’ve doomed us all!
# 1320 POC2_SC7_263  How much do you know about Davy Jones?
# 1330 POC3_SC14_777  You can do nothing without the key!
# 1340 POC3_SC14_795  William! My son!
# 1350 POC2_SC13_562  Yes, they’re signed ‘Lord Cutler Beckett of the East India Trading Company.’
# 1360 POC3_SC14_805  Belay that, or we’ll be a sitting duck.
# 1370 POC2_SC9_416  I know what I want.
# 1380 POC2_SC8_296  Not so well as I’d hoped.  Come.
# 1390 POC1_SC10_315  He was a bloody pirate, a scallywag.
# 1400 POC1_SC22_710  You can?t beat me, Jack .
# 1410 POC3_SC7_128  Malfaiteur en Tombeau, Crocher l’Esplanade, Dans l’Fond d’l’eau!
# 1420 POC3_SC9_257  Rum’s gone too.
# 1430 POC3_SC14_790  Do you?  Heady tonic, holding life and death in the palm of one’s hand.
# 1440 POC2_SC8_389   Uh, Mr. Gibbs?
# 1450 POC2_SC5_114  You would risk your life to save Sparrow’s does not mean that he would do the same for anyone else. Now, where’s that dog with the keys?
# 1460 POC1_SC20_638  Ol? Bootstrap Bill . We knew him. Never sat well with Bootstrap what we did to Jack Sparrow , the mutiny and all. He said it wasn?t right with the Code. That?s why he sent off a piece of the treasure to you as it were. He said we deserved to be cursed? and remain cursed.
# 1470 POC2_SC11_502  To save Will.
# 1480 POC1_SC7_240  And how does a maid come to own a trinket such as that. Family heirloom, perhaps?
# 1490 POC1_SC17_512  You can tell them that after they?ve caught us.
# 1500 POC2_SC8_283  It’s me front I’m worried about.
# 1510 POC2_SC6_175  So I did.  A marriage interrupted.  Or fate intervenes.  You’re making great efforts to ensure Jack Sparrow’s freedom.
# 1520 POC1_SC6_205  She wants to be taken to the Captain. And she?ll go without a fuss. We must honor the Code.
# 1530 POC2_SC8_328   Black spot.
# 1540 POC3_SC14_807  But captain...
# 1550 POC3_SC9_441  Captain? Her!
# 1560 POC1_SC20_648  I don?t care for the situation. Any attempt to storm the caves could turn to an ambush.
# 1570 POC3_SC8_150  This truly is a Godforsaken place.
# 1580 POC1_SC1_3  Mr. Gibbs , that will do!
# 1590 POC2_SC16_724  You aren’t pulling hard enough.
# 1600 POC3_SC8_140  Aye captain.
# 1610 POC1_SC18_587  It goes with your black heart.
# 1620 POC3_SC9_370  There’s no honor in remaining with the losing side. Leaving it for the winning side, that’s just good business.
# 1630 POC2_SC16_780  Hyah! Come on!  Come and get me! I’m over here. Come on!
# 1640 POC2_SC4_83  Ah. So it’s you, then. He shanghaied you into service, eh?
# 1650 POC2_SC9_420  Thanks very much.
# 1660 POC1_SC8_254  No?the pirates who invaded this Fort left Sparrow locked in his cell ergo they are not his allies. Governor, we will establish their most likely course?
# 1670 POC2_SC12_558  They’ll know you helped me.
# 1680 POC2_SC16_788  It’s a lot of open water.
# 1690 POC1_SC17_552  Elizabeth !
# 1700 POC2_SC14_643  Aha.
# 1710 POC3_SC11_488  Come with me.  Quickly!
# 1720 POC3_SC14_737  Think like the whelp... think like the whelp... think like the whelp... half barrel hinges... leverage!  Wish me luck, boys, I’ll need it.
# 1730 POC1_SC6_181  The Black Pearl ? I?ve heard stories. She?s been preying on ships and settlements for near ten years. Never leaves any survivors.
# 1740 POC1_SC13_376  Actually -  borrowed. Borrowed without permission. But with every intention of bringing it back to you.
# 1750 POC3_SC9_279  Ten years years is a long time, mate.
# 1760 POC3_SC9_268  Come again?
# 1770 POC1_SC17_542  She?s not what they?re after.
# 1780 POC3_SC11_496  You’re lying.
# 1790 POC3_SC13_638  It’s not just about living forever, Jackie. The trick is, living with yourself, forever.
# 1800 POC3_SC5_96  Ever gazed upon the green flash, Master Gibbs?
# 1810 POC1_SC6_170  It is a smart match. He?s a fine man; he?s what any woman should dream of marrying.
# 1820 POC3_SC14_740  Nobody move! I dropped me brain.
# 1830 POC3_SC13_606  Aye!
# 1840 POC2_SC16_739   Make fast!
# 1850 POC3_SC9_398  And you can accomplish all this, can you?
# 1860 POC1_SC2_54  About the day we met, do you remember?
# 1870 POC1_SC19_612  Mr. Sparrow ?I?m not entirely sure that I?ve had enough rum to allow that kind of talk.
# 1880 POC3_SC9_235  It’s my father, we’ve made it back. Father here, look here!
# 1890 POC1_SC16_488   What sort of a man trades a man?s life for a ship?
# 1900 POC3_SC9_337  Jack Sparrow, you paid me great insult once.
# 1910 POC1_SC9_296   Search every cabin, every hold, down to the bilges.  Sailors, back to the Interceptor! Now!
# 1920 POC1_SC3_90  What?s your name?
# 1930 POC3_SC13_591  And what fate have you planned for your captors?
# 1940 POC2_SC16_765  Will!
# 1950 POC1_SC13_391  What?s in your head that?s put you in such a fine mood, Captain?
# 1960 POC1_SC18_569  You can?t. I can.
# 1970 POC1_SC20_653  Coward! The commodore ordered ? I have to tell him! The pirates! They?re cursed! They cannot be killed!
# 1980 POC1_SC6_167  Well, I meant you being threatened by that pirate. Sounds terrifying.
# 1990 POC3_SC10_478  Mate, if you choose to lock your heart away, you’ll lose it for certain. If I may lend a machete to your intellectual thicket—avoid the choice altogether. Change the facts. Let someone else dispatch Jones.
# 2000 POC3_SC8_137  Man the yards, you filthy toads!
# 2010 POC2_SC13_584  Oh, don’t be absurd, I trust him, that’s all.
# 2020 POC2_SC11_471  I’m deeply flattered, son, but my first and only love is the sea.
# 2030 POC3_SC14_761  I can set you free, mate.
# 2040 POC2_SC4_68  The Black Pearl?
# 2050 POC2_SC8_279   Her?
# 2060 POC3_SC14_767  I’m a little busy at the moment!
# 2070 POC2_SC11_505  We have our heading.
# 2080 POC2_SC6_189  Come on!  It’s ours for the taking!
# 2090 POC1_SC15_426  Gentlemen, the time has come! Our salvation is nigh! Our torment is near at end.
# 2100 POC1_SC13_384  Aye!
# 2110 POC3_SC13_593  My heart will always belong to you.
# 2120 POC1_SC24_754  Move!
# 2130 POC2_SC8_353   Douse the lamps.
# 2140 POC2_SC6_170  Or else I would not still be here. You sent Will to get you the compass and buy Jack Sparrow, it Will do you no good.
# 2150 POC3_SC13_582  My sweet, you come for me.
# 2160 POC3_SC8_164  There has been a perpetual and virulent lack of discipline aboard my vessel! Why is that, sir?
# 2170 POC3_SC9_319  You stupid fish!
# 2180 POC2_SC13_570  A truly discomforting notion, love.
# 2190 POC3_SC9_410  Excuse me?
# 2200 POC3_SC14_677  Go away!
# 2210 POC2_SC10_466  Where is the chest.
# 2220 POC3_SC14_787  That’s why I brought this!
# 2230 POC2_SC12_529  Aye, anyone.
# 2240 POC1_SC22_694   A moment, please. Elizabeth ? I just want you to know I, uh, I believe you made a very good decision today. Couldn?t be more proud of you.  But, you know, even a good decision if made for the wrong reasons can be a wrong decision.
# 2250 POC3_SC9_245  Someone cast a line!
# 2260 POC2_SC15_719  Here you go.
# 2270 POC3_SC14_828  It’s just good business...
# 2280 POC1_SC9_286   This is either madness or brilliance.
# 2290 POC3_SC14_710  You’re right. Then what shall we die for?  You will listen to me. Listen! The brethren will still be looking here to us, to the Black Pearl to lead, and what will they see? Frightened bilge rats aboard a derelict ship? No! They will see free men, and freedom. And what the enemy will see is the flash of our cannons, they will hear the ring of our swords and they will know what we can do! By the sweat of our brows, and the strength of our backs, and the courage of our hearts... gentlemen, hoist the colors!
# 2300 POC3_SC3_41  More steam!
# 2310 POC1_SC22_716  Any port in the storm.
# 2320 POC1_SC18_559   If any of you as much as thinks the word ?parley,? I?ll have your guts for garters.
# 2330 POC2_SC4_79  I had some help retrieving the Pearl, by the way. Your son.
# 2340 POC2_SC4_100  Jack’s hat! Steer about!
# 2350 POC1_SC15_466  The oars have gone missing. Find them!
# 2360 POC2_SC8_367  I-I-I Will serve.
# 2370 POC1_SC23_731
# 2380 POC1_SC7_220  I didn?t know we was takin? on captives.
# 2390 POC1_SC6_201  Parley. I invoke the right of parley. According to the Code of the brethren, set down by the pirates Morgan and Bartholomew , you have to take me to your Captain.
# 2400 POC1_SC21_668  Shut up! You?re next.
# 2410 POC2_SC10_448  The cat’s out of the bag, Mr. Turner. Your issue Will feel its sting be it at the Bo’sun’s hand or your own.
# 2420 POC2_SC14_644  No no no no no. “Kroken”’s how it’s pronounced in the original Scandinavian, and “Kraken”’s closer to that.
# 2430 POC2_SC4_87  Technically, I –

# %%
# SBert predictions
sentence = "Where is my ship ?"
picked = nns_trf.nearest(sentence_vector_trnf(embedder, sentence), 5)[0]
response_line_id = responses[picked]

print("Your line:\n\t", sentence)
print("Most similar turn:\n\t", all_poc_lines[picked])
print("Response to most similar turn:\n\t", all_poc_lines[response_line_id])
# Out:
# Your line:
# 	 Where is my ship ?
# Most similar turn:
# 	  Where does it make berth?
# Response to most similar turn:
# 	  Where does it make berth? Have you not heard the stories? Captain Barbossa and his crew of miscreants sail from the dreaded Isla de Muerta . It?s an island that cannot be found except by those who already know where it is.

# %%
# Get 5 nearest semantic responses
picked_list_nns_trf = nns_trf.nearest(sentence_vector_trnf(embedder, sentence), 5)
picked_list_nns = nns.nearest(sentence_mean(nlp, sentence), 5)

# %%
# Five closest responses using SBert
choice_count = 1
for choice in picked_list_nns_trf:
  response_line_id = responses[choice]
  print(choice_count)
  print("Most similar turn:\n\t", all_poc_lines[choice])
  print("Response to most similar turn:\n\t", all_poc_lines[response_line_id])
  choice_count += 1
# Out:
# 1
# Most similar turn:
# 	  Where does it make berth?
# Response to most similar turn:
# 	  Where does it make berth? Have you not heard the stories? Captain Barbossa and his crew of miscreants sail from the dreaded Isla de Muerta . It?s an island that cannot be found except by those who already know where it is.
# 2
# Most similar turn:
# 	  Which ship do we follow?
# Response to most similar turn:
# 	  Signal the Dutchman to track down Sao Feng. We follow the Pearl. How soon can we have the ship ready to pursue?
# 3
# Most similar turn:
# 	  Where are ye goin’?
# Response to most similar turn:
# 	   You’ve got to tell me what’s happening.
# 4
# Most similar turn:
# 	   Where’s the Commodore?
# Response to most similar turn:
# 	   Fell behind.
# 5
# Most similar turn:
# 	  Which port?
# Response to most similar turn:
# 	  I didn’t say port. I said land, any land.  Ah!
